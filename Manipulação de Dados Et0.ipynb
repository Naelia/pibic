# %% [markdown]
# ## Manipulação de Dados Et0

# %%
# Importando os módulos
import csv
import pandas as pd
import matplotlib.pyplot as plt    
import numpy as np  
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
dados = pd.read_csv('Dados/Dataset.csv')

# %%
# Verificando o formato dos dados
dados.shape
# Out:
# (10367, 17)

# %%
# Verificando as primeiras linhas do dataset
dados
# Out:
#                  TIMESTAMP   RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 0      2015-02-24 22:00:00  13253.0     600.8486     600.3632        0.000
# 1      2015-02-24 23:00:00  13254.0     600.7875     600.4396        0.000
# 2      2015-02-25 00:00:00  13255.0     601.1295     600.7021        0.254
# 3      2015-02-25 01:00:00  13256.0     601.1752     600.4365        0.000
# 4      2015-02-25 02:00:00  13257.0     601.1813     600.6227        0.000
# ...                    ...      ...          ...          ...          ...
# 10362  2016-10-19 07:00:00  23615.0     620.3572     599.7344        0.000
# 10363  2016-10-19 08:00:00  23616.0     619.8627     599.7466        0.000
# 10364  2016-10-19 09:00:00  23617.0     619.9329     599.7344        0.000
# 10365  2016-10-19 10:00:00  23618.0     619.8840     599.7802        0.000
# 10366  2016-10-19 11:00:00  23619.0     620.4030     599.7253        0.000
#
# ...

# %%
dados['TIMESTAMP'] <= '2016-10-19'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10362    False
# 10363    False
# 10364    False
# 10365    False
# 10366    False
# Name: TIMESTAMP, Length: 10367, dtype: bool

# %%
# Verificando se existem valores nulos
dados.isnull().values.any()
# Out:
# True

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados
# Out:
#                  TIMESTAMP   RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 0      2015-02-24 22:00:00  13253.0     600.8486     600.3632        0.000
# 1      2015-02-24 23:00:00  13254.0     600.7875     600.4396        0.000
# 2      2015-02-25 00:00:00  13255.0     601.1295     600.7021        0.254
# 3      2015-02-25 01:00:00  13256.0     601.1752     600.4365        0.000
# 4      2015-02-25 02:00:00  13257.0     601.1813     600.6227        0.000
# ...                    ...      ...          ...          ...          ...
# 10362  2016-10-19 07:00:00  23615.0     620.3572     599.7344        0.000
# 10363  2016-10-19 08:00:00  23616.0     619.8627     599.7466        0.000
# 10364  2016-10-19 09:00:00  23617.0     619.9329     599.7344        0.000
# 10365  2016-10-19 10:00:00  23618.0     619.8840     599.7802        0.000
# 10366  2016-10-19 11:00:00  23619.0     620.4030     599.7253        0.000
#
# ...

# %%
dados_filtrados = dados[(dados['TIMESTAMP'] >= '2016-06-16') & (dados['TIMESTAMP'] <= '2016-10-19')]
dados_filtrados.shape
# Out:
# (3000, 17)

# %%
dados_filtrados
# Out:
#                  TIMESTAMP   RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 7355   2016-06-16 00:00:00  20608.0     600.6594     599.9939          0.0
# 7356   2016-06-16 01:00:00  20609.0     600.9829     600.2259          0.0
# 7357   2016-06-16 02:00:00  20610.0     600.6807     600.2900          0.0
# 7358   2016-06-16 03:00:00  20611.0     600.8853     600.2015          0.0
# 7359   2016-06-16 04:00:00  20612.0     600.9280     600.6990          0.0
# ...                    ...      ...          ...          ...          ...
# 10350  2016-10-18 19:00:00  23603.0     620.1130     599.7375          0.0
# 10351  2016-10-18 20:00:00  23604.0     620.0947     599.8138          0.0
# 10352  2016-10-18 21:00:00  23605.0     619.8962     599.7680          0.0
# 10353  2016-10-18 22:00:00  23606.0     620.3724     599.7711          0.0
# 10354  2016-10-18 23:00:00  23607.0     619.9176     599.7985          0.0
#
# ...

# %%
# Removendo os dados inconsistente de precipitação
dados_filtrados = dados_filtrados[dados_filtrados['Rain_mm_Tot'] <= 1]
dados_filtrados.shape
# Out:
# (2997, 17)

# %%
# Removendo os dados inconsistente velocidade do vento
dados_filtrados = dados_filtrados[dados_filtrados['WS_ms_Avg'] <=4]
dados_filtrados.shape
# Out:
# (2997, 17)

# %%
dados_filtrados['BP_mbar_Max'].max()
# Out:
# 625.1313

# %%
# Removendo os dados inconsistente da Pressão atmosférica máxima
dados_filtrados = dados_filtrados[dados_filtrados['BP_mbar_Max'] <= 625.000]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
# Removendo os dados inconsistente da Radiação solar média
dados_filtrados = dados_filtrados[dados_filtrados['SlrkJ_Avg'] <= 25.4809]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['SlrkJ_Tot'].max()
# Out:
# 7807.995

# %%
# Removendo os dados inconsistente da Radiação solar total
dados_filtrados = dados_filtrados[dados_filtrados['SlrkJ_Tot'] <= 6000000]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['TdC_Min'].max()
# Out:
# 22.81481

# %%
# Removendo os dados inconsistente da Temperatura mínima
dados_filtrados = dados_filtrados[dados_filtrados['TdC_Min'] <= 23.4105]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['RH_Avg'].max()
# Out:
# 99.10529

# %%
# Removendo os dados inconsistente da Umidade relativa média
dados_filtrados = dados_filtrados[dados_filtrados['RH_Avg'] <= 99.8006]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['TdC_Max'].max()
# Out:
# 24.43459

# %%
# Removendo os dados inconsistente da Temperatura máxima
dados_filtrados = dados_filtrados[dados_filtrados['TdC_Max'] <= 24.8820]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['AirTC_Min'].max()
# Out:
# 36.691

# %%
# Removendo os dados inconsistente da Temperatura do ar mínima
dados_filtrados = dados_filtrados[dados_filtrados['AirTC_Min'] >= 1]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
# Removendo os dados inconsistente da Temperatura do ar mínima
dados_filtrados = dados_filtrados[dados_filtrados['AirTC_Min'] <= 36.692]
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
dados_filtrados['AirTC_Max'].max()
# Out:
# 23993.0

# %%
# Removendo os dados inconsistente da Temperatura do ar maxima
dados_filtrados = dados_filtrados[dados_filtrados['AirTC_Max'] >= 1
                                ]

# %%
#Nenhum dado removido
dados_filtrados.shape
# Out:
# (2996, 17)

# %%
# Removendo os dados inconsistente da Temperatura do ar maxima
dados_filtrados = dados_filtrados[dados_filtrados['AirTC_Max'] <= 37.965]

# %%
dados_filtrados.shape
# Out:
# (2995, 17)

# %%
dados_filtrados['RH_Min'].min()
# Out:
# 6.96

# %%
# Removendo os dados inconsistente da Umidade relativa mínima
dados_filtrados = dados_filtrados[dados_filtrados['RH_Min'] <= 87.062]

# %%
dados_filtrados.shape
# Out:
# (2682, 17)

# %%
dados_filtrados['RH_Max'].max()
# Out:
# 98.13600000000001

# %%
# Removendo os dados inconsistente da Umidade relativa maxima
dados_filtrados = dados_filtrados[dados_filtrados['RH_Max'] <= 95.5]

# %%
# Fim da remoçaõ dos dados iconsitente
dados_filtrados.shape
# Out:
# (2674, 17)

# %%
dados_filtrados
# Out:
#                  TIMESTAMP   RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 7355   2016-06-16 00:00:00  20608.0     600.6594     599.9939          0.0
# 7356   2016-06-16 01:00:00  20609.0     600.9829     600.2259          0.0
# 7364   2016-06-16 09:00:00  20617.0     620.2503     599.8565          0.0
# 7365   2016-06-16 10:00:00  20618.0     620.2747     599.7650          0.0
# 7366   2016-06-16 11:00:00  20619.0     619.9084     599.7802          0.0
# ...                    ...      ...          ...          ...          ...
# 10350  2016-10-18 19:00:00  23603.0     620.1130     599.7375          0.0
# 10351  2016-10-18 20:00:00  23604.0     620.0947     599.8138          0.0
# 10352  2016-10-18 21:00:00  23605.0     619.8962     599.7680          0.0
# 10353  2016-10-18 22:00:00  23606.0     620.3724     599.7711          0.0
# 10354  2016-10-18 23:00:00  23607.0     619.9176     599.7985          0.0
#
# ...

# %%
dados_filtrados=dados_filtrados.drop(columns=['TIMESTAMP'])
dados_filtrados.head()
# Out:
#        RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  \
# 7355  20608.0     600.6594     599.9939          0.0     24.703     24.124
# 7356  20609.0     600.9829     600.2259          0.0     24.434     23.682
# 7364  20617.0     620.2503     599.8565          0.0     28.380     26.456
# 7365  20618.0     620.2747     599.7650          0.0     29.859     27.208
# 7366  20619.0     619.9084     599.7802          0.0     30.388     27.820
#
#       RH_Max  RH_Min  SlrkJ_Tot   TdC_Max   TdC_Min  AirTC_Avg    RH_Avg  \
# 7355  86.426  82.296   1602.694  21.99709  21.34611   24.48126  84.18771
# 7356  89.355  85.546   1585.170  22.29312  21.44312   23.96824  88.16695
# 7364  79.804  66.886   6394.357  23.18920  21.28450   27.33409  73.79070
# 7365  70.023  59.288   3865.619  22.37438  20.18821   28.55962  64.01627
# 7366  64.503  55.519   3447.535  21.63211  20.03454   29.31881  59.57275
#
#       WS_ms_Avg  SlrkJ_Avg       Eto
# 7355   0.000000   4.451927  0.002190
# ...

# %%
dados_filtrados.set_index('RECORD')
# Out:
#          BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  RH_Max  \
# RECORD
# 20608.0     600.6594     599.9939          0.0     24.703     24.124  86.426
# 20609.0     600.9829     600.2259          0.0     24.434     23.682  89.355
# 20617.0     620.2503     599.8565          0.0     28.380     26.456  79.804
# 20618.0     620.2747     599.7650          0.0     29.859     27.208  70.023
# 20619.0     619.9084     599.7802          0.0     30.388     27.820  64.503
# ...              ...          ...          ...        ...        ...     ...
# 23603.0     620.1130     599.7375          0.0     33.148     30.439  47.296
# 23604.0     620.0947     599.8138          0.0     30.400     28.490  56.494
# 23605.0     619.8962     599.7680          0.0     28.478     26.456  69.207
# 23606.0     620.3724     599.7711          0.0     26.456     25.666  74.726
# 23607.0     619.9176     599.7985          0.0     25.676     24.954  80.070
#
# ...

# %%
dados_filtrados.iloc[0:1871]
# Out:
#        RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  \
# 7355  20608.0     600.6594     599.9939          0.0     24.703     24.124
# 7356  20609.0     600.9829     600.2259          0.0     24.434     23.682
# 7364  20617.0     620.2503     599.8565          0.0     28.380     26.456
# 7365  20618.0     620.2747     599.7650          0.0     29.859     27.208
# 7366  20619.0     619.9084     599.7802          0.0     30.388     27.820
# ...       ...          ...          ...          ...        ...        ...
# 9502  22755.0     620.0916     599.8412          0.0     32.080     29.220
# 9503  22756.0     620.0610     599.8046          0.0     33.657     31.589
# 9504  22757.0     620.0671     599.8412          0.0     34.505     32.718
# 9505  22758.0     620.0916     599.8535          0.0     36.322     33.577
# 9506  22759.0     600.9493     599.8168          0.0     36.520     34.416
#
# ...

# %%
X = dados_filtrados.iloc[0:1871]
Y = dados_filtrados.iloc[1871:2674]

# %%
X
# Out:
#        RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  \
# 7355  20608.0     600.6594     599.9939          0.0     24.703     24.124
# 7356  20609.0     600.9829     600.2259          0.0     24.434     23.682
# 7364  20617.0     620.2503     599.8565          0.0     28.380     26.456
# 7365  20618.0     620.2747     599.7650          0.0     29.859     27.208
# 7366  20619.0     619.9084     599.7802          0.0     30.388     27.820
# ...       ...          ...          ...          ...        ...        ...
# 9502  22755.0     620.0916     599.8412          0.0     32.080     29.220
# 9503  22756.0     620.0610     599.8046          0.0     33.657     31.589
# 9504  22757.0     620.0671     599.8412          0.0     34.505     32.718
# 9505  22758.0     620.0916     599.8535          0.0     36.322     33.577
# 9506  22759.0     600.9493     599.8168          0.0     36.520     34.416
#
# ...

# %%
Y
# Out:
#         RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  \
# 9507   22760.0     620.0671     599.8626          0.0     37.388     35.414
# 9508   22761.0     620.1038     599.8901          0.0     36.990     34.953
# 9509   22762.0     600.9677     599.7863          0.0     35.534     33.876
# 9510   22763.0     620.0916     599.7802          0.0     34.015     29.701
# 9511   22764.0     620.4518     599.8443          0.0     29.689     27.290
# ...        ...          ...          ...          ...        ...        ...
# 10350  23603.0     620.1130     599.7375          0.0     33.148     30.439
# 10351  23604.0     620.0947     599.8138          0.0     30.400     28.490
# 10352  23605.0     619.8962     599.7680          0.0     28.478     26.456
# 10353  23606.0     620.3724     599.7711          0.0     26.456     25.666
# 10354  23607.0     619.9176     599.7985          0.0     25.676     24.954
#
# ...

# %%
# Criando o modelo
modelo = LinearRegression()

# %%
type(modelo)
# Out:
# sklearn.linear_model.base.LinearRegression

# %%
# Treinando o modelo
modelo.fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-9a4760aa35b6> in <module>
#       1 # Treinando o modelo
# ----> 2 modelo.fit(X, Y)
#
# ~\Miniconda3\envs\pibic\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Miniconda3\envs\pibic\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     727         y = y.astype(np.float64)
#     728
# ...
