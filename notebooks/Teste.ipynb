# %%
# Importando os módulos
import csv
import pandas as pd
import numpy as np  
import statistics
from statistics import median

# %% [markdown]
# # Importação dos dados

# %%
df_data = pd.read_csv('../dados/datasetteste.csv')
df_data.head()
# Out:
#              TIMESTAMP  RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 0  2015-02-24 22:00:00   13253     600.8486     600.3632        0.000
# 1  2015-02-24 23:00:00   13254     600.7875     600.4396        0.000
# 2  2015-02-25 00:00:00   13255     601.1295     600.7021        0.254
# 3  2015-02-25 01:00:00   13256     601.1752     600.4365        0.000
# 4  2015-02-25 02:00:00   13257     601.1813     600.6227        0.000
#
#   AirTC_Max AirTC_Min  RH_Max  RH_Min  SlrkJ_Tot  TdC_Max  TdC_Min AirTC_Avg  \
# 0    23.472    23.341  99.998  99.998   0.193834   23.472   23.341  23.39763
# 1    23.472     23.26  99.998  99.998   0.137363   23.472   23.260   23.3635
# 2    23.371    23.212  99.998  99.998   0.137363   23.371   23.212  23.29213
# 3    23.402    23.292  99.998  99.998   0.202992   23.402   23.292  23.34686
# 4     23.35    23.212  99.998  99.998   0.203755   23.350   23.212   23.2819
#
#      RH_Avg  WS_ms_Avg  SlrkJ_Avg           Eto
# ...

# %%
df_data = df_data.loc[0:10]

# %%
df_data.shape
# Out:
# (11, 17)

# %%
delta = 4

# %%
df_data['BP_mbar_Max(min)'] = 0
df_data['BP_mbar_Max(max)'] = 0
df_data['BP_mbar_Max(med)'] = 0
df_data['BP_mbar_Max(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,2],df_data.iloc[x-2,2],df_data.iloc[x-3,2],df_data.iloc[x-4,2]]
    df_data.iloc[x,17] = min(lista)
    df_data.iloc[x,18] = max(lista)
    df_data.iloc[x,19] = sum(lista)/len(lista) 
    df_data.iloc[x,20] = statistics.stdev(lista)

# %%
df_data['BP_mbar_Min(min)'] = 0
df_data['BP_mbar_Min(max)'] = 0
df_data['BP_mbar_Min(med)'] = 0
df_data['BP_mbar_Min(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,3],df_data.iloc[x-2,3],df_data.iloc[x-3,3]]
    df_data.iloc[x,21] = min(lista)
    df_data.iloc[x,22] = max(lista)
    df_data.iloc[x,23] = sum(lista)/len(lista) 
    df_data.iloc[x,24] = statistics.stdev(lista)

# %%
df_data['Rain_mm_Tot(min)'] = 0
df_data['Rain_mm_Tot(max)'] = 0
df_data['Rain_mm_Tot(med)'] = 0
df_data['Rain_mm_Tot(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,4],df_data.iloc[x-2,4],df_data.iloc[x-3,4]]
    df_data.iloc[x,25] = min(lista)
    df_data.iloc[x,26] = max(lista)
    df_data.iloc[x,27] = sum(lista)/len(lista) 
    df_data.iloc[x,28] = statistics.stdev(lista)

# %%
df_data['AirTC_Max(min)'] = 0
df_data['AirTC_Max(max)'] = 0
df_data['AirTC_Max(med)'] = 0
df_data['AirTC_Max(dp)'] = 0

# %%
df_data['AirTC_Max'] = df_data['AirTC_Max'].astype(np.float64)
df_data['AirTC_Max(min)'] = df_data['AirTC_Max(min)'].astype(np.float64)
df_data['AirTC_Max(max)'] = df_data['AirTC_Max(max)'].astype(np.float64)
df_data['AirTC_Max(med)'] = df_data['AirTC_Max(med)'].astype(np.float64)
df_data['AirTC_Max(dp)'] = df_data['AirTC_Max(dp)'].astype(np.float64)

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,5],df_data.iloc[x-2,5],df_data.iloc[x-3,5]]
    df_data.iloc[x,29] = min(lista)
    df_data.iloc[x,30] = max(lista)
    df_data.iloc[x,31] = sum(lista)/len(lista) 
    df_data.iloc[x,32] = statistics.stdev(lista)

# %%
df_data['AirTC_Min(min)'] = 0
df_data['AirTC_Min(max)'] = 0
df_data['AirTC_Min(med)'] = 0
df_data['AirTC_Min(dp)'] = 0

# %%
df_data['AirTC_Min'] = df_data['AirTC_Min'].astype(np.float64)
df_data['AirTC_Min(min)'] = df_data['AirTC_Min(min)'].astype(np.float64)
df_data['AirTC_Min(max)'] = df_data['AirTC_Min(max)'].astype(np.float64)
df_data['AirTC_Min(med)'] = df_data['AirTC_Min(med)'].astype(np.float64)
df_data['AirTC_Min(dp)'] = df_data['AirTC_Min(dp)'].astype(np.float64)

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,6],df_data.iloc[x-2,6],df_data.iloc[x-3,6]]
    df_data.iloc[x,33] = min(lista)
    df_data.iloc[x,34] = max(lista)
    df_data.iloc[x,35] = sum(lista)/len(lista) 
    df_data.iloc[x,36] = statistics.stdev(lista)

# %%
df_data['RH_Max(min)'] = 0
df_data['RH_Max(max)'] = 0
df_data['RH_Max(med)'] = 0
df_data['RH_Max(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,7],df_data.iloc[x-2,7],df_data.iloc[x-3,7]]
    df_data.iloc[x,37] = min(lista)
    df_data.iloc[x,38] = max(lista)
    df_data.iloc[x,39] = sum(lista)/len(lista) 
    df_data.iloc[x,40] = statistics.stdev(lista)

# %%
df_data['RH_Min(min)'] = 0
df_data['RH_Min(max)'] = 0
df_data['RH_Min(med)'] = 0
df_data['RH_Min(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,8],df_data.iloc[x-2,8],df_data.iloc[x-3,8]]
    df_data.iloc[x,41] = min(lista)
    df_data.iloc[x,42] = max(lista)
    df_data.iloc[x,43] = sum(lista)/len(lista) 
    df_data.iloc[x,44] = statistics.stdev(lista)

# %%
df_data['SlrkJ_Tot(min)'] = 0
df_data['SlrkJ_Tot(max)'] = 0
df_data['SlrkJ_Tot(med)'] = 0
df_data['SlrkJ_Tot(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,9],df_data.iloc[x-2,9],df_data.iloc[x-3,9]]
    df_data.iloc[x,45] = min(lista)
    df_data.iloc[x,46] = max(lista)
    df_data.iloc[x,47] = sum(lista)/len(lista) 
    df_data.iloc[x,48] = statistics.stdev(lista)

# %%
df_data['TdC_Max(min)'] = 0
df_data['TdC_Max(max)'] = 0
df_data['TdC_Max(med)'] = 0
df_data['TdC_Max(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,10],df_data.iloc[x-2,10],df_data.iloc[x-3,10]]
    df_data.iloc[x,49] = min(lista)
    df_data.iloc[x,50] = max(lista)
    df_data.iloc[x,51] = sum(lista)/len(lista) 
    df_data.iloc[x,52] = statistics.stdev(lista)

# %%
df_data['TdC_Min(min)'] = 0
df_data['TdC_Min(max)'] = 0
df_data['TdC_Min(med)'] = 0
df_data['TdC_Min(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,11],df_data.iloc[x-2,11],df_data.iloc[x-3,11]]
    df_data.iloc[x,53] = min(lista)
    df_data.iloc[x,54] = max(lista)
    df_data.iloc[x,55] = sum(lista)/len(lista) 
    df_data.iloc[x,56] = statistics.stdev(lista)

# %%
df_data['AirTC_Avg(min)'] = 0
df_data['AirTC_Avg(max)'] = 0
df_data['AirTC_Avg(med)'] = 0
df_data['AirTC_Avg(dp)'] = 0

# %%
df_data['AirTC_Avg'] = df_data['AirTC_Avg'].astype(np.float64)
df_data['AirTC_Avg(min)'] = df_data['AirTC_Avg(min)'].astype(np.float64)
df_data['AirTC_Avg(max)'] = df_data['AirTC_Avg(max)'].astype(np.float64)
df_data['AirTC_Avg(med)'] = df_data['AirTC_Avg(med)'].astype(np.float64)
df_data['AirTC_Avg(dp)'] = df_data['AirTC_Avg(dp)'].astype(np.float64)

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,12],df_data.iloc[x-2,12],df_data.iloc[x-3,12]]
    df_data.iloc[x,57] = min(lista)
    df_data.iloc[x,58] = max(lista)
    df_data.iloc[x,59] = sum(lista)/len(lista) 
    df_data.iloc[x,60] = statistics.stdev(lista)

# %%
df_data['RH_Avg(min)'] = 0
df_data['RH_Avg(max)'] = 0
df_data['RH_Avg(med)'] = 0
df_data['RH_Avg(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,13],df_data.iloc[x-2,13],df_data.iloc[x-3,13]]
    df_data.iloc[x,61] = min(lista)
    df_data.iloc[x,62] = max(lista)
    df_data.iloc[x,63] = sum(lista)/len(lista) 
    df_data.iloc[x,64] = statistics.stdev(lista)

# %%
df_data['WS_ms_Avg(min)'] = 0
df_data['WS_ms_Avg(max)'] = 0
df_data['WS_ms_Avg(med)'] = 0
df_data['WS_ms_Avg(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,14],df_data.iloc[x-2,14],df_data.iloc[x-3,14]]
    df_data.iloc[x,65] = min(lista)
    df_data.iloc[x,66] = max(lista)
    df_data.iloc[x,67] = sum(lista)/len(lista) 
    df_data.iloc[x,68] = statistics.stdev(lista)

# %%
df_data['SlrkJ_Avg(min)'] = 0
df_data['SlrkJ_Avg(max)'] = 0
df_data['SlrkJ_Avg(med)'] = 0
df_data['SlrkJ_Avg(dp)'] = 0

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,15],df_data.iloc[x-2,15],df_data.iloc[x-3,15]]
    df_data.iloc[x,69] = min(lista)
    df_data.iloc[x,70] = max(lista)
    df_data.iloc[x,71] = sum(lista)/len(lista) 
    df_data.iloc[x,72] = statistics.stdev(lista)

# %%
df_data['Eto(min)'] = 0
df_data['Eto(max)'] = 0
df_data['Eto(med)'] = 0
df_data['Eto(dp)'] = 0

# %%
df_data['Eto'] = df_data['Eto'].astype(np.float64)
df_data['Eto(min)'] = df_data['Eto(min)'].astype(np.float64)
df_data['Eto(max)'] = df_data['Eto(max)'].astype(np.float64)
df_data['Eto(med)'] = df_data['Eto(med)'].astype(np.float64)
df_data['Eto(dp)'] = df_data['Eto(dp)'].astype(np.float64)

# %%
for x in range(delta,df_data.shape[0]): 
    lista = [df_data.iloc[x-1,16],df_data.iloc[x-2,16],df_data.iloc[x-3,16]]
    df_data.iloc[x,73] = min(lista)
    df_data.iloc[x,74] = max(lista)
    df_data.iloc[x,75] = sum(lista)/len(lista) 
    df_data.iloc[x,76] = statistics.stdev(lista)

# %%
df_data
# Out:
#               TIMESTAMP  RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 0   2015-02-24 22:00:00   13253     600.8486     600.3632        0.000
# 1   2015-02-24 23:00:00   13254     600.7875     600.4396        0.000
# 2   2015-02-25 00:00:00   13255     601.1295     600.7021        0.254
# 3   2015-02-25 01:00:00   13256     601.1752     600.4365        0.000
# 4   2015-02-25 02:00:00   13257     601.1813     600.6227        0.000
# 5   2015-02-25 03:00:00   13258     601.2881     600.5769        0.000
# 6   2015-02-25 04:00:00   13259     601.3248     600.6349        0.000
# 7   2015-02-25 05:00:00   13260     601.3004     600.4945        0.000
# 8   2015-02-25 06:00:00   13261     601.2241     600.4152        0.000
# 9   2015-02-25 07:00:00   13262     601.6545     600.2869        0.000
# 10  2015-02-25 08:00:00   13263     601.5568     600.2289        0.254
#
#     AirTC_Max  AirTC_Min  RH_Max  RH_Min   SlrkJ_Tot  ...  WS_ms_Avg(med)  \
# ...

# %%
df_data.iloc[:, :16]
# Out:
#               TIMESTAMP  RECORD  BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  \
# 0   2015-02-24 22:00:00   13253     600.8486     600.3632        0.000
# 1   2015-02-24 23:00:00   13254     600.7875     600.4396        0.000
# 2   2015-02-25 00:00:00   13255     601.1295     600.7021        0.254
# 3   2015-02-25 01:00:00   13256     601.1752     600.4365        0.000
# 4   2015-02-25 02:00:00   13257     601.1813     600.6227        0.000
# 5   2015-02-25 03:00:00   13258     601.2881     600.5769        0.000
# 6   2015-02-25 04:00:00   13259     601.3248     600.6349        0.000
# 7   2015-02-25 05:00:00   13260     601.3004     600.4945        0.000
# 8   2015-02-25 06:00:00   13261     601.2241     600.4152        0.000
# 9   2015-02-25 07:00:00   13262     601.6545     600.2869        0.000
# 10  2015-02-25 08:00:00   13263     601.5568     600.2289        0.254
#
#     AirTC_Max  AirTC_Min  RH_Max  RH_Min   SlrkJ_Tot  TdC_Max  TdC_Min  \
# ...

# %%
df_data.iloc[:, 2:18]
# Out:
#     BP_mbar_Max  BP_mbar_Min  Rain_mm_Tot  AirTC_Max  AirTC_Min  RH_Max  \
# 0      600.8486     600.3632        0.000     23.472     23.341  99.998
# 1      600.7875     600.4396        0.000     23.472     23.260  99.998
# 2      601.1295     600.7021        0.254     23.371     23.212  99.998
# 3      601.1752     600.4365        0.000     23.402     23.292  99.998
# 4      601.1813     600.6227        0.000     23.350     23.212  99.998
# 5      601.2881     600.5769        0.000     23.312     23.222  99.998
# 6      601.3248     600.6349        0.000     23.392     23.251  99.998
# 7      601.3004     600.4945        0.000     23.402     23.191  99.998
# 8      601.2241     600.4152        0.000     23.232     23.050  99.998
# 9      601.6545     600.2869        0.000     23.441     23.010  99.998
# 10     601.5568     600.2289        0.254     23.993     23.392  99.998
#
#     RH_Min   SlrkJ_Tot  TdC_Max  TdC_Min  AirTC_Avg    RH_Avg  WS_ms_Avg  \
# ...

# %%
def preenche(column,y):
    for row in range(delta,df_data.shape[0]): 
        lista = [df_data.iloc[row-1,column]]
        for column in range(y,1):
            df_data.iloc[row,y] = min(lista)
            df_data.iloc[row,y] = max(lista)
            df_data.iloc[row,y] = sum(lista)/len(lista) 
            df_data.iloc[row,y] = statistics.stdev(lista)
